# %% [markdown]
# ### Prompt Templates
#
# https://langchain-doc.readthedocs.io/en/latest/modules/prompts.html

# %% [markdown]
# ### Chat models
#
# https://langchain-doc.readthedocs.io/en/latest/modules/chat.html?highlight=chat%20models#

# %% [markdown]
# ![interface](../figures/chat_interface.png)

# %% [markdown]
# ### Langchain pipe

# %% [markdown]
# ![langchain_pipe](../figures/langchain_pipe.png)

# %% [markdown]
# ### Langchain workflow

# %% [markdown]
# ![Langchain_workflow](../figures/Langchain_workflow.png)

# %% [markdown]
# ### Ollama
#
# https://ollama.com/
#
# https://ollama.com/library/gemma3

# %% [markdown]
# ### Download a model
#
# > ollama pull gemma3:4b
# > ollama list
# > ollama run gemma3:4b

# %% [markdown]
# ### Download and list
#
# (base) flavio@flavio:~/Downloads$ ollama pull gemma3:4b
# ```
# pulling manifest
# pulling aeda25e63ebd: 100% ▕████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ 3.3 GB
# pulling e0a42594d802: 100% ▕████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  358 B
# pulling dd084c7d92a3: 100% ▕████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ 8.4 KB
# pulling 3116c5225075: 100% ▕████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   77 B
# pulling b6ae5839783f: 100% ▕████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success
# ```
#
# (base) flavio@flavio:~/Downloads$ ollama list
# ```
# NAME                ID              SIZE      MODIFIED
# gemma3:4b           a2af6cc3eb7f    3.3 GB    8 seconds ago
# deepseek-r1:1.5b    e0979632db5a    1.1 GB    2 weeks ago
# llama3.2:latest     a80c4f17acd5    2.0 GB    2 weeks ago
# codellama:latest    8fdf8f752f6e    3.8 GB    2 weeks ago
# ```
