# %%
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama


load_dotenv()
# Out:
# True

# %%
import langchain

langchain.__version__
# Out:
# '1.2.10'

# %%
information=\
'''Foundation models are large-scale AI models trained on vast, typically unlabeled, data using self-supervised learning, acting as a flexible base for diverse, specialized applications. Coined by Stanford researchers in 2021, these models (e.g., GPT, BERT) use transfer learning to perform tasks like text synthesis, image generation, and code generation. 

Key Characteristics

Massive Scale: Trained on enormous, broad datasets allowing them to learn general patterns, representations, and structures.
Versatility: One model can be adapted, fine-tuned, or prompted for many downstream tasks (e.g., Q&A, translation, classification).
Adaptation: Often fine-tuned on smaller, task-specific datasets to improve performance in niche domains.
Common Architectures: Generally built on transformers, neural networks, and increasingly, multimodal data. 

Examples and Use Cases
Language Generation/Analysis: GPT series (OpenAI), BERT (Google).
Image Generation: Stable Diffusion, Midjourney.
Applications: Customer service, software development (code debugging), data analysis, and healthcare diagnostics. 

Advantages and Challenges
Advantages: Reduces the need for labeled data, increases accessibility for developers, and accelerates AI adoption across industries.
Challenges: High computational costs for training, risks of inheriting societal biases, potential misinformation, and, in some cases, limited transparency. 
Foundation models are considered the key technology driving the current wave of generative AI, acting as the foundation upon which more specific applications are built.'''

summary_template = \
'''Given the following information, summarize it in a concise manner: 
focus on the key characteristics, examples, and advantages/challenges of foundation models.'''

# %%
summary_prompt_template = PromptTemplate(
    input_variables=["information"],
    template=summary_template,
)

# %%
want = "OpenAI"
want = "Gemma3"

if want == "OpenAI":
    llm = ChatOpenAI(model="gpt-5", temperature=0.1)
elif want == "Gemma3":
    llm = ChatOllama(model="gemma3:4b", temperature=0.1)

# %% [markdown]
# ### Langchain expression model
#
# What is the advantage of using LCEL syntax | compared to calling each component separately?
#
# It creats a reusable, composable pipeline with automatic data flow and error handling

# %%
chain = summary_prompt_template | llm

# %% [markdown]
# ### What happens when you call chain.invoke(input={"information": information})?
#
# I executes the entire chain: formats the prompt with the input, then sends it to the LLM

# %%
response = chain.invoke(input={"information": information})

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
print("Foundation Models Summary:\n")
print(response.content)
# Out:
# Foundation Models Summary:
#
# Okay, here's a concise summary of foundation models, incorporating key characteristics, examples, and advantages/challenges:
#
# **Foundation Models: A Quick Overview**
#
# Foundation models are **large AI models** (typically based on deep learning – often transformers) trained on **massive datasets of unlabeled data** (text, images, audio, etc.). They’re “foundational” because they can be adapted (fine-tuned) for a *huge* range of downstream tasks with relatively little task-specific data.
#
# **Key Characteristics:**
#
# * **Scale:**  They’re characterized by their enormous size – billions or even trillions of parameters.
# * **Self-Supervised Learning:** Primarily trained using self-supervised learning, predicting missing parts of data or relationships within it.
# * **Emergent Abilities:** Surprisingly, they often exhibit abilities not explicitly programmed, like basic reasoning or translation, simply due to their scale.
#
#
# **Examples:**
#
# * **GPT-3/4 (OpenAI):** Text generation, chatbots, code generation.
# * **PaLM (Google):**  Advanced reasoning, question answering, code generation.
# * **DALL-E 2/Midjourney (OpenAI/Midjourney):** Image generation from text prompts.
# * **CLIP (OpenAI):** Connecting text and images.
#
#
#
# **Advantages:**
#
# * **Few-Shot/Zero-Shot Learning:** Can perform tasks with very little or no task-specific training data.
# * **Versatility:** Adaptable to a wide variety of applications – from content creation to scientific discovery.
# * **Reduced Development Costs:**  Fine-tuning is cheaper than training a model from scratch.
#
#
#
# **Challenges:**
#
# * **Computational Cost:** Training and running these models is *extremely* expensive (requiring significant computing power and energy).
# * **Bias & Fairness:** Inherit biases present in their training data, leading to potentially harmful outputs.
# * **Hallucinations/Accuracy:** Can generate incorrect or misleading information (hallucinations).
# * **Interpretability:**  Difficult to understand *why* they make certain decisions.
# * **Ethical Concerns:**  Potential for misuse (deepfakes, misinformation).
#
#
#
# ---
#
# Would you like me to elaborate on a specific aspect of foundation models, such as:
#
# *   A particular example (e.g., GPT-4)?
# *   A specific challenge (e.g., bias mitigation)?
