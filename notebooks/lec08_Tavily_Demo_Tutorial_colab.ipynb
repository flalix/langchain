# %% [markdown]
# # 🗺️ TavilyMap & TavilyExtract Tutorial
#
# > **📚 Part of the LangChain Course: Building AI Agents & RAG Apps**
# > [🎓 Get the full course](https://www.udemy.com/course/langchain/?referralCode=D981B8213164A3EA91AC)
#
#
# This notebook demonstrates two powerful tools from Tavily AI:
# - **TavilyMap**: Automatically discovers and maps website structures
# - **TavilyExtract**: Extracts clean, structured content from web pages
#
# Perfect for documentation scraping, research, and content extraction! 🚀
#
# ---

# %% [markdown]
# ## 📦 Setup & Installation
#
# First, let's install the required packages and set up our environment.

# %%
# !pip install langchain-tavily certifi
# Out:
# Collecting langchain-tavily
#   Downloading langchain_tavily-0.2.17-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (2026.2.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (3.13.3)
# Requirement already satisfied: langchain<2.0.0,>=0.3.20 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.15 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (1.2.18)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (2.32.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.23.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.20->langchain-tavily) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=0.3.20->langchain-tavily) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=0.3.20->langchain-tavily) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=0.3.20->langchain-tavily) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=0.3.20->langchain-tavily) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.20->langchain-tavily) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.15->langchain-tavily) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain<2.0.0,>=0.3.20->langchain-tavily) (1.12.2)
# Downloading langchain_tavily-0.2.17-py3-none-any.whl (30 kB)
# Installing collected packages: langchain-tavily
# Successfully installed langchain-tavily-0.2.17

# %%
# For pretty printing and visualization
# !pip install rich
# Out:
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.19.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import asyncio
import os
import ssl
from typing import Any, Dict, List

import certifi
from langchain_tavily import TavilyExtract, TavilyMap
from rich.console import Console
from rich.panel import Panel

# Configure SSL context
ssl_context = ssl.create_default_context(cafile=certifi.where())
os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

# Initialize rich console for pretty printing
console = Console()


print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## 🔑 API Key Setup
#
# You'll need a Tavily API key to use these tools. Get yours at [tavily.com](https://app.tavily.com/home?utm_campaign=eden_marco&utm_medium=socials&utm_source=linkedin).
#
# Set environment variable `TAVILY_API_KEY`

# %%
# Set directly (uncomment and add your key)
# tavily_api_key = "your_tavily_api_key_here"

# os.environ["TAVILY_API_KEY"] = "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"

from google.colab import userdata

os.environ["TAVILY_API_KEY"] = userdata.get('TAVILY_API_KEY')

# %% [markdown]
# ## 🗺️ TavilyMap: Website Structure Discovery
#
# TavilyMap automatically discovers and maps website structures by crawling through links. It's perfect for:
# - Documentation sites
# - Blog archives
# - Knowledge bases
# - Any structured website
#
# ### Key Parameters:
# - `max_depth`: How deep to crawl (default: 3)
# - `max_breadth`: How many links per page (default: 10)
# - `max_pages`: Maximum total pages to discover (default: 100)

# %%
# Initialize TavilyMap with custom settings
tavily_map = TavilyMap(
    max_depth=3,        # Crawl up to 3 levels deep
    max_breadth=15,     # Follow up to 15 links per page
    max_pages=50        # Limit to 50 total pages for demo
)

print("✅ TavilyMap initialized successfully!")
# Out:
# ✅ TavilyMap initialized successfully!

# %% [markdown]
# ### 📊 Demo: Mapping a Documentation Site
#
# Let's map the structure of a popular documentation site. We'll use the FastAPI documentation as an example.

# %%
# Example website to map
URL = "https://python.langchain.com/docs/introduction/"

console.print(f"🔍 Mapping website structure for: {URL}", style="bold blue")
console.print("This may take a moment...")

# Map the website structure
site_map = tavily_map.invoke(URL)

# Display results
urls = site_map.get('results', [])
console.print(f"\n✅ Successfully mapped {len(urls)} URLs!", style="bold green")

# Show first 10 URLs as examples
console.print("\n📋 First 50 discovered URLs:", style="bold yellow")
for i, url in enumerate(urls[:50], 1):
    console.print(f"  {i:2d}. {url}")

console.print(f"  ... and {len(urls)} URLs")
# Out:
# 🔍 Mapping website structure for: https://python.langchain.com/docs/introduction/
# This may take a moment...
# ✅ Successfully mapped 19 URLs!
# 📋 First 50 discovered URLs:
#    1. https://python.langchain.com/docs/introduction
#    2. https://python.langchain.com/use-these-docs
#    3. https://python.langchain.com/langsmith/observability
#    4. https://python.langchain.com/langsmith/home
#    5. https://python.langchain.com/oss/python/learn
#    6. https://python.langchain.com/oss/python/langchain/mcp
#    7. https://python.langchain.com/oss/python/langchain/test
#    8. https://python.langchain.com/oss/python/contributing/overview
#    9. https://python.langchain.com/oss/python/langchain/quickstart
#   10. https://python.langchain.com/oss/python/langchain/retrieval
#   11. https://python.langchain.com/oss/python/langchain/observability
#   12. https://python.langchain.com/oss/python/langchain/models
#   13. https://python.langchain.com/oss/python/langchain/runtime
#   14. https://python.langchain.com/oss/python/langchain/deploy
#   15. https://python.langchain.com/oss/python/langchain/long-term-memory
#   16. https://python.langchain.com/oss/python/langchain/short-term-memory
#   17. https://python.langchain.com/oss/python/langchain/overview
#   18. https://python.langchain.com/oss/python/langchain/install
#   19. https://python.langchain.com/oss/python/langchain/studio
#   ... and 19 URLs

# %% [markdown]
# ## 🔍 TavilyExtract: Clean Content Extraction
#
# TavilyExtract takes URLs and returns clean, structured content without ads, navigation, or other noise. Perfect for:
# - Documentation processing
# - Content analysis
# - Research and data collection
# - Building knowledge bases
#
# ### Key Features:
# - Removes HTML markup and navigation
# - Extracts main content only
# - Handles JavaScript-rendered content
# - Batch processing support

# %%
# Initialize TavilyExtract
tavily_extract = TavilyExtract()

print("✅ TavilyExtract initialized successfully!")
# Out:
# ✅ TavilyExtract initialized successfully!

# %% [markdown]
# ### 📄 Demo: Extracting Content from URLs
#
# Let's extract clean content from some of the URLs we discovered earlier.

# %%
# Select a few interesting URLs for extraction
iurl=8
sample_urls = [urls[iurl]]  # Take first 5 URLs
console.print(f"📚 Extracting content from {len(sample_urls)} URLs...", style="bold blue")

# Extract content
dic_extract = await tavily_extract.ainvoke(input={"urls": sample_urls})

# Display results
extracted_docs = dic_extract.get('results', [])
console.print(f"\n✅ Successfully extracted {len(extracted_docs)} documents!", style="bold green")

# Show summary of each extracted document
for i, doc in enumerate(extracted_docs, 1):
    url = doc.get('url', 'Unknown')
    content = doc.get('raw_content', '')

    # Create a panel for each document
    panel_content = f"""URL: {url}
Content Length: {len(content):,} characters
Preview: {content}..."""

    console.print(Panel(panel_content, title=f"Document {i}", border_style="blue"))
    print()  # Add spacing
# Out:
# 📚 Extracting content from 1 URLs...
# ✅ Successfully extracted 1 documents!
# ╭────────────────────────────────────────────────── Document 1 ───────────────────────────────────────────────────╮
# │ URL: https://python.langchain.com/oss/python/langchain/quickstart                                               │
# │ Content Length: 2,714 characters                                                                                │
# │ Preview:                                                                                                        │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut │
# │ o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)                                            │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au │
# │ to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)                                           │
# │ !(https://mintlify.s3.us-west-1.amazonaws.com/langchain-5e9cc07a/images/brand/langchain-icon.png)               │
# │                                                                                                                 │
# │ Python                                                                                                          │
# │                                                                                                                 │
# │ ##### Get started                                                                                               │
# │                                                                                                                 │
# │ ##### Core components                                                                                           │
# │                                                                                                                 │
# │ ##### Middleware                                                                                                │
# │                                                                                                                 │
# │ ##### Advanced usage                                                                                            │
# │                                                                                                                 │
# │ ##### Agent development                                                                                         │
# │                                                                                                                 │
# │ ##### Deploy with LangSmith                                                                                     │
# │                                                                                                                 │
# │ # LangChain overview                                                                                            │
# │                                                                                                                 │
# │ LangChain is an open source framework with a prebuilt agent architecture and integrations for any model or      │
# │ tool—so you can build agents that adapt as fast as the ecosystem evolves                                        │
# │                                                                                                                 │
# │ ## [​](#create-an-agent) Create an agent                                                                         │
# │                                                                                                                 │
# │ `# pip install -qU langchain "langchain"                                                                        │
# │ from langchain.agents import create_agent                                                                       │
# │                                                                                                                 │
# │ def get_weather(city: str) -> str:                                                                              │
# │  """Get weather for a given city."""                                                                            │
# │  return f"It's always sunny in {city}!"                                                                         │
# │                                                                                                                 │
# │ agent = create_agent(                                                                                           │
# │  model="claude-sonnet-4-6",                                                                                     │
# │  tools=,                                                                                                        │
# │  system_prompt="You are a helpful assistant",                                                                   │
# │ )                                                                                                               │
# │                                                                                                                 │
# │ # Run the agent                                                                                                 │
# │ agent.invoke(                                                                                                   │
# │  {"messages": [{"role": "user", "content": "what is the weather in sf"}]}                                       │
# │ )`                                                                                                              │
# │ `LANGSMITH_TRACING=true`                                                                                        │
# │                                                                                                                 │
# │ ## [​](#core-benefits) Core benefits                                                                             │
# │                                                                                                                 │
# │ ## Standard model interface                                                                                     │
# │                                                                                                                 │
# │ ## Easy to use, highly flexible agent                                                                           │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langgraph-icon.png?fit=max&auto=format&n │
# │ =nQm-sjd_MByLhgeW&q=85&s=b997e1a7487d507a36556eedbfd99f81)                                                      │
# │                                                                                                                 │
# │ ## Built on top of LangGraph                                                                                    │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/observability-icon-dark.png?fit=max&auto │
# │ =format&n=nQm-sjd_MByLhgeW&q=85&s=ccbc183bca2a5e4ca78d30149e3836cc)                                             │
# │                                                                                                                 │
# │ ## Debug with LangSmith                                                                                         │
# │                                                                                                                 │
# │ Was this page helpful?                                                                                          │
# │                                                                                                                 │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-dark-blue.png?fit=max&aut │
# │ o=format&n=nQm-sjd_MByLhgeW&q=85&s=5babf1a1962208fd7eed942fa2432ecb)                                            │
# │ !(https://mintcdn.com/langchain-5e9cc07a/nQm-sjd_MByLhgeW/images/brand/langchain-docs-light-blue.png?fit=max&au │
# │ to=format&n=nQm-sjd_MByLhgeW&q=85&s=0bcd2a1f2599ed228bcedf0f535b45b1)                                           │
# │                                                                                                                 │
# │ Resources                                                                                                       │
# │                                                                                                                 │
# │ Company...                                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### ⚡ Batch Processing Demo
#
# For larger datasets, we can process URLs in batches to optimize performance and handle rate limits.

# %%
def chunk_urls(urls: List[str], chunk_size: int = 3) -> List[List[str]]:
    """Split URLs into chunks of specified size."""
    chunks = []
    for i in range(0, len(urls), chunk_size):
        chunk = urls[i:i + chunk_size]
        chunks.append(chunk)
    return chunks

async def extract_batch(batch_url_list: List[str], batch_num: int) -> List[Dict[str, Any]]:
    """Extract documents from a batch of URLs."""
    try:
        console.print(f"🔄 Processing batch {batch_num} with {len(batch_url_list)} URLs", style="blue")
        docs = await tavily_extract.ainvoke(input={"urls": batch_url_list})
        results = docs.get('results', [])
        console.print(f"✅ Batch {batch_num} completed - extracted {len(results)} documents", style="green")
        return results
    except Exception as e:
        console.print(f"❌ Batch {batch_num} failed: {e}", style="red")
        return []

# Process a larger set of URLs in batches
url_batches = chunk_urls(urls[:9], chunk_size=3) # Take first 9 URLs for batch demo, split to batches of 3

console.print(f"📦 Processing 9 URLs in {len(url_batches)} batches", style="bold yellow")

# Process batches concurrently
tasks = [extract_batch(batch, i + 1) for i, batch in enumerate(url_batches)]
batch_results = await asyncio.gather(*tasks)

# Flatten results
all_extracted = []
for batch_result in batch_results:
    all_extracted.extend(batch_result)

console.print(f"\n🎉 Batch processing complete! Total documents extracted: {len(all_extracted)}", style="bold green")
# Out:
# 📦 Processing 9 URLs in 3 batches
# 🔄 Processing batch 1 with 3 URLs
# 🔄 Processing batch 2 with 3 URLs
# 🔄 Processing batch 3 with 3 URLs
# ✅ Batch 1 completed - extracted 3 documents
# ✅ Batch 2 completed - extracted 3 documents
# ✅ Batch 3 completed - extracted 3 documents
# 🎉 Batch processing complete! Total documents extracted: 9

# %% [markdown]
# ## 🎯 Real-World Use Cases
#
# Here are some practical applications of TavilyMap and TavilyExtract:
#
# ### 1. Documentation Scraping
# - Map entire documentation sites
# - Extract clean content for search indexes
# - Build knowledge bases from existing docs
#
# ### 2. Competitive Analysis
# - Map competitor websites
# - Extract product information
# - Monitor content changes
#
# ### 3. Research & Content Collection
# - Gather information from multiple sources
# - Build datasets for analysis
# - Create content archives
#
# ### 4. SEO & Site Analysis
# - Discover all pages on a site
# - Analyze content structure
# - Identify content gaps

# %% [markdown]
# ## 🎯 Conclusion
#
# This tutorial demonstrated the power of TavilyMap and TavilyExtract for automated web content discovery and extraction:
#
# ### Key Takeaways:
#
# 1. **TavilyMap** is perfect for:
#    - Discovering website structures
#    - Finding all pages on a site
#    - Site auditing
#
# 2. **TavilyExtract** excels at:
#    - Clean content extraction
#    - Removing HTML noise
#    - Batch processing
#    - Structured data collection
#
# 3. **Combined** they enable:
#    - Complete documentation scraping
#    - Automated content pipelines
#    - Knowledge base creation
#    - Research automation
#
# ### Next Steps:
# - Integrate with vector databases for semantic search
# - Add content filtering and classification
# - Build monitoring systems for content changes
# - Create automated reporting dashboards
#
# ---
#
# **Happy scraping!** 🚀
